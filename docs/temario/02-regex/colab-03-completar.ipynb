# %% [markdown]
# # Regex en Python — 3. Completar huecos
#
# Tercer paso de una progresión de cuatro notebooks. El código está escrito. Los patrones, no.
#
# ---
#
# En cada tarea hay una línea con `"___"`. Hay que reemplazar `___` con el patrón correspondiente.

# %%
corpus = """
🚀 El término "influencer" lleva tres años en los corpus académicos y sigue sin traducción estable. #NeoLogismos #LenguaDigital https://t.co/abc123 - 12/03/2024
@linguista_pro De acuerdo: "ghosting" ya aparece en el DRAE con marca coloquial. Fuente: https://dle.rae.es/ghosting - 03-04-2024
Thread sobre préstamos del inglés: "woke" pasó del activismo anglosajón al debate público español en menos de dos años. Sin traducción consensuada. https://www.lengua.es/anglicismos-2024 #anglicismos #LenguaViva
El fenómeno "phishing" no es solo tecnológico: las mismas técnicas de de suplantación aparecen en campañas de desinformación lingüística. - 5 de abril de 2024.
¿Alguien más nota que "scrollear" ya no necesita explicación? Antes era jerga de redes, ahora aparece en medios generalistas sin comillas. #neologismos https://t.co/xyz789 - 12/3/2024
@traductor_es El problema con "deepfake" es la traducción: ¿ultrafalsificación? ¿simulacro profundo? Ninguna cuaja. El anglicismo gana por defecto. 7-4-2024
Términos digitales consolidados en el español formal durante 2024: "streaming", "podcast", "newsletter". Ya en medios de referencia sin comillas ni cursiva. 12 de marzo de 2024. #LenguajeDigital https://fundeu.es/recomendaciones
🧵 Sobre "mansplaining": ¿préstamo léxico o calco conceptual? La Academia aún no se ha pronunciado. La presencia en corpus crece crece año a año. - 04/04/2024
"Selfie" entró al DRAE en 2014, diez años antes que "ghosting". La velocidad de canonicalización ha aumentado notablemente en la última década. #DRAE #NeoLogismos - 15/03/2024
📢 @corpus_es La palabra "meme" -primer registro en corpus académico español: 2012- ya aparece en todos los registros sin marca de préstamo. https://academic.oup.com/loquens/meme-esp - 18-03-2024
El "burnout" aparece en informes de recursos humanos, en diagnósticos clínicos y en conversaciones de WhatsApp. Tres registros, un único anglicismo. Sin equivalente estable en español. - 20/03/2024
¿Es "spoiler" un préstamo o ya es español? La RAE lo recoge como coloquial. El verbo derivado "espoilear" no aparece aparece aún en ningún diccionario normativo. #neologismos - 22-03-2024
🔍 Búsqueda en CREA: "hater" aparece 43 veces entre 2015 y 2023. "Odiador", propuesta de la Fundéu, aparece 3 veces. Los corpus no mienten. https://www.rae.es/banco-de-datos/crea - 25/03/2024
@trad_digital El debate sobre "fake news" se complica: ¿es una unidad léxica o dos palabras? La Fundéu propone "bulo", con tradición y precisión. Pero "fake news" sigue ganando en frecuencia. - 26-03-2024
"Trolling" plantea un problema morfológico: el verbo en español sería "trolear" (atestiguado) o "troliar" (marginal). El sustantivo "trol" ya está en el DRAE. Sin consenso en el gerundio. - 28/03/2024
📝 Estudio de frecuencia: "networking" aparece más en ofertas de empleo en español que en inglés para puestos equivalentes. El anglicismo ha desplazado a "contactos profesionales" en ese registro. https://t.co/net456 #LenguajeLaboral - 29-03-2024
El "spam" pasó de nombre a verbo ("spamear") y a adjetivo ("spameado") en menos de una década. La morfología española absorbió el anglicismo sin resistencia. #corpus - 1 de abril de 2024.
@lingüista_mx ¿Se puede hablar de "spanglish" como lengua o solo como fenómeno de contacto? La diferencia importa para la política lingüística. https://www.hispanismo.org/spanglish - 2-4-2024
💬 "Coaching" y "mentoring" conviven en el mismo documento sin que nadie los distinga. En corpus corporativos de 2023, aparecen juntos en el 67% de los casos. - 3 de abril de 2024.
El "rebranding" de palabras existe: "propaganda" se convirtió en "comunicación estratégica" y "despido" en "desvinculación". El eufemismo también tiene corpus. #lenguaje - 5/04/2024
@fundeu_rae La Fundéu recomienda "teletrabajo" sobre "remote work" desde 2020. Cuatro años después, ambos coexisten en corpus periodísticos. La recomendación normativa y el uso real divergen. https://www.fundeu.es/recomendacion/teletrabajo - 7/04/2024
🌐 "Hashtag" tiene traducción oficial en francés (mot-dièse) y propuesta en español (etiqueta). En corpus reales, "hashtag" supera a "etiqueta" en proporción 9:1. Las traducciones institucionales no siempre cuajan cuajan en el uso. - 8/04/2024
"Storytelling" se ha gramaticalizado como modificador nominal: estrategia de storytelling, taller de storytelling, consultor de storytelling. Aparece en corpus universitarios sin cursiva ni comillas. - 9-04-2024
@linglab_es Nuevo artículo: anglicismos del ámbito deportivo con mayor penetración en el español: "ranking", "training", "pressing", "dribbling". Todos con morfología adaptada. https://revista.linguistica.es/anglicismos-deporte - 10/04/2024
📝 El "crowdfunding" y el "crowdsourcing" comparten prefijo pero no frecuencia: el primero aparece 12 veces más en corpus periodístico. La especialización semántica también tiene corpus. #lenguajeDigital - 11 de abril de 2024.
"""

import re

# %% [markdown]
# ---
#
# ## Tarea 1 — Palabras duplicadas
#
# El corpus contiene errores de edición habituales en texto digital: palabras que aparecen dos veces seguidas. Para detectarlos, el patrón necesita recordar lo que acaba de capturar.

# %%
patron = r"___"

resultados = re.findall(patron, corpus)
print(resultados)
print(len(resultados))

# %% [markdown]
# ¿Hay en el corpus algún caso donde la repetición podría ser intencionada y no un error?

# %% [markdown]
# ---
#
# ## Tarea 2 — Fechas en cualquier formato numérico
#
# El corpus contiene fechas con separadores `/` y `-`, y con uno o dos dígitos en día y mes: `12/03/2024`, `03-04-2024`, `12/3/2024`, `7-4-2024`.

# %%
patron = r"___"

resultados = re.findall(patron, corpus)
print(resultados)
print(len(resultados))

# %% [markdown]
# ¿Qué formatos de fecha del corpus han quedado fuera del patrón?

# %% [markdown]
# ---
#
# ## Tarea 3 — Siglas y acrónimos
#
# El corpus menciona DRAE, CREA y otras instituciones en mayúsculas. Un patrón basado en clases de caracteres y cuantificadores permite localizarlos.

# %%
patron = r"___"

resultados = re.findall(patron, corpus)
print(resultados)
print(len(resultados))

# %% [markdown]
# ¿Qué aparece en los resultados además de DRAE y CREA? ¿Es ruido o información?

# %% [markdown]
# ---
#
# ## Tarea 4 — Fechas en formato textual
#
# El corpus contiene fechas escritas con palabras: *5 de abril de 2024*, *12 de marzo de 2024*. El patrón numérico de la tarea 2 no las captura. Construir un patrón que sí lo haga.

# %%
patron = r"___"

resultados = re.findall(patron, corpus)
print(resultados)
print(len(resultados))

# %% [markdown]
# ¿Podría un único patrón capturar tanto las fechas numéricas como las textuales?

# %% [markdown]
# ---
#
# ## Tarea 5 — Verbos derivados de anglicismos
#
# El español adapta anglicismos convirtiéndolos en verbos mediante el sufijo *-ear*: *scrollear*, *espoilear*, *spamear*. Construir un patrón que capture esa clase de palabras.

# %%
patron = r"___"

resultados = re.findall(patron, corpus)
print(resultados)
print(len(resultados))

# %% [markdown]
# *troliar* no coincide con el patrón. ¿Qué implica que el mismo anglicismo genere dos verbos con sufijos distintos?

# %% [markdown]
# ---
#
# ## Tarea 6 — Menciones y hashtags
#
# En los notebooks anteriores se buscaron menciones (`@\w+`) y hashtags (`#\w+`) con dos patrones distintos. Ambos comparten estructura: un símbolo seguido de una secuencia alfanumérica. Construir un único patrón que capture los dos.

# %%
patron = r"___"

resultados = re.findall(patron, corpus)
print(resultados)
print(len(resultados))

# %% [markdown]
# ¿El patrón unificado captura exactamente lo mismo que los dos patrones por separado, o hay diferencias?

# %% [markdown]
# ---
#
# ## Tarea 7 — Años del corpus
#
# El corpus cita estudios, estadísticas y fechas de canonicalización. Los años aparecen tanto como componente de una fecha numérica como de forma independiente. Construir un patrón que los capture todos.

# %%
patron = r"___"

resultados = re.findall(patron, corpus)
print(resultados)
print(len(resultados))

# %% [markdown]
# ¿Cuántos de los resultados son años autónomos y cuántos son el componente año de una fecha numérica? ¿Tiene esa distinción relevancia para el análisis?

# %% [markdown]
# ---
#
# ## Tarea 8 — Nominalizaciones en *-ción*
#
# El registro académico y técnico produce nominalizaciones: sustantivos abstractos que nombran procesos o conceptos. En español, muchos terminan en *-ción*. Construir un patrón que los localice en el corpus.

# %%
patron = r"___"

resultados = re.findall(patron, corpus)
print(resultados)
print(len(resultados))

# %% [markdown]
# ¿En qué tipos de contexto aparecen las nominalizaciones del corpus: definición, contraste, evaluación? ¿Qué dice eso del registro del texto?

# %% [markdown]
# ---
#
# ## Tarea 9 — Términos en *-ismo*
#
# El metalenguaje lingüístico usa *-ismo* para nombrar fenómenos y actitudes: *anglicismo*, *activismo*, *eufemismo*. Construir un patrón que los capture sin incluir palabras como *mismo*.
#
# > El patrón debe garantizar que haya al menos dos caracteres antes del sufijo.

# %%
patron = r"___"

resultados = re.findall(patron, corpus)
print(resultados)
print(len(resultados))

# %% [markdown]
# *hispanismo* aparece en el corpus dentro de una URL, no en texto corrido. ¿Importa esa diferencia para un análisis terminológico? ¿Cómo lo distinguirías?

# %% [markdown]
# ---
#
# ## Tarea 10 — URLs completas
#
# El corpus incluye referencias a fuentes externas. Construir un patrón que capture cada URL completa, desde el protocolo hasta el final de la ruta, tanto si empieza por *http* como por *https*.

# %%
patron = r"___"

resultados = re.findall(patron, corpus)
print(resultados)
print(len(resultados))

# %% [markdown]
# ¿Cuántas URLs apuntan a fuentes académicas o institucionales? ¿Qué tipo de legitimación aporta la cita de fuentes en este tipo de texto?

# %% [markdown]
# ---
#
# ## Tarea 11 — Fuentes en dominio *.es*
#
# De los resultados de la tarea anterior, varias URLs pertenecen a instituciones españolas con dominio *.es*. Construir un patrón que extraiga solo ese componente del dominio.
#
# > El punto antes de *es* tiene significado especial en regex. Para buscarlo como carácter literal hay que indicarlo explícitamente.

# %%
patron = r"___"

resultados = re.findall(patron, corpus)
print(resultados)
print(len(resultados))

# %% [markdown]
# ¿Qué instituciones del corpus no tienen dominio *.es*? ¿Qué dice eso sobre la distribución geográfica de las fuentes?

# %% [markdown]
# ---
#
# ## Tarea 12 — Contenido entre paréntesis
#
# El corpus usa paréntesis para glosarios, equivalencias y etiquetas metalingüísticas: *(atestiguado)*, *(mot-dièse)*. Construir un patrón que capture todo lo que aparece entre paréntesis, incluyendo los propios paréntesis.
#
# > El patrón necesita indicar qué caracteres se aceptan dentro. Una clase negada `[^)]` captura cualquier carácter excepto el paréntesis de cierre.

# %%
patron = r"___"

resultados = re.findall(patron, corpus)
print(resultados)
print(len(resultados))

# %% [markdown]
# ¿El contenido entre paréntesis es siempre metalingüístico? ¿Hay casos donde cumpla otra función?

# %% [markdown]
# ## #2Think
#
# - Las tareas 2 y 4 capturan el mismo concepto —una fecha— con patrones distintos. ¿Existe un patrón que unifique ambos formatos? ¿Compensa el coste en legibilidad?
# - Los resultados de la tarea 3 mezclan siglas con ruido. ¿Depende de lo que se considere ruido del análisis que se quiera hacer, o es ruido independientemente del contexto?
# - Las tareas 10 y 11 trabajan sobre el mismo material en dos niveles: URL completa y dominio aislado. ¿Qué preguntas responde cada nivel? ¿Cuándo interesa uno y cuándo el otro?
# - Un mismo corpus produce resultados distintos según el patrón elegido. ¿En qué medida el patrón construye el objeto de análisis en lugar de simplemente encontrarlo?
#
# ---
#
# En el siguiente notebook no hay huecos ni marcas. Hay un corpus y una tarea abierta.
